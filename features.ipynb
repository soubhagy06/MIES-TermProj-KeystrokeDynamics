# %%
import numpy as np
import pandas as pd
import csv
from date_time import timevalue 
from process import categorize
from process import lr_holdtime

# %%
fr=open('date4.txt','rb')   # date file of person whose features to train
info=fr.readlines() 
fw=open('info.csv','wb')

in_txt=csv.reader(info,delimiter='\t')
out_csv=csv.writer(fw)
out_csv.writerows(in_txt)

fr.close()
fw.close()

# %%
columns=['Event_Type','Key_Code','Shift','Alt','Control','Time']

# %%
df=pd.read_csv('info.csv')

# %%
df
# Out:
#        KeyDown  163  False False.1 False.2   Oct Sat 1:00:24:28.379067  \
# 0      KeyDown   68  False   False    True   Oct Sat 1:00:24:28.582078
# 1        KeyUp   68  False   False    True   Oct Sat 1:00:24:28.693084
# 2        KeyUp  163  False   False    True   Oct Sat 1:00:24:28.758088
# 3      KeyDown  163  False   False   False   Oct Sat 1:00:24:32.350294
# 4      KeyDown   87  False   False    True   Oct Sat 1:00:24:32.686313
# 5        KeyUp   87  False   False    True   Oct Sat 1:00:24:32.789319
# 6        KeyUp  163  False   False    True   Oct Sat 1:00:24:32.813320
# 7      KeyDown  163  False   False   False   Oct Sat 1:00:24:41.805834
# 8      KeyDown   68  False   False    True   Oct Sat 1:00:24:42.061849
# 9        KeyUp   68  False   False    True   Oct Sat 1:00:24:42.173856
# 10       KeyUp  163  False   False    True   Oct Sat 1:00:24:42.223858
# 11     KeyDown  163  False   False   False   Oct Sat 1:00:24:45.846066
# 12     KeyDown   87  False   False    True   Oct Sat 1:00:24:46.326093
# 13       KeyUp   87  False   False    True   Oct Sat 1:00:24:46.461101
# 14       KeyUp  163  False   False    True   Oct Sat 1:00:24:46.533105
# 15     KeyDown   78  False   False   False   Oct Sat 1:00:25:15.869783
# 16       KeyUp   78  False   False   False   Oct Sat 1:00:25:15.997790
# 17     KeyDown    9  False   False   False   Oct Sat 1:00:25:16.325809
# 18       KeyUp    9  False   False   False   Oct Sat 1:00:25:16.429815
# 19     KeyDown   81  False   False   False   Oct Sat 1:00:25:16.621826
# 20       KeyUp   81  False   False   False   Oct Sat 1:00:25:16.709831
# 21     KeyDown   83  False   False   False   Oct Sat 1:00:25:16.741833
# 22       KeyUp   83  False   False   False   Oct Sat 1:00:25:16.829838
# 23     KeyDown   70  False   False   False   Oct Sat 1:00:25:16.893841
# 24       KeyUp   70  False   False   False   Oct Sat 1:00:25:17.005848
# 25     KeyDown   78  False   False   False   Oct Sat 1:00:25:17.006848
# 26       KeyUp   78  False   False   False   Oct Sat 1:00:25:17.109854
# 27     KeyDown   74  False   False   False   Oct Sat 1:00:25:17.221860
# 28       KeyUp   74  False   False   False   Oct Sat 1:00:25:17.293864
# 29     KeyDown   69  False   False   False   Oct Sat 1:00:25:17.365868
# ...        ...  ...    ...     ...     ...                         ...
# 40674    KeyUp   33  False   False   False  Oct Sun 30:18:36:08.628929
# 40675  KeyDown   69  False   False   False  Oct Sun 30:18:36:08.651930
# 40676  KeyDown   33  False   False   False  Oct Sun 30:18:36:08.664931
# 40677    KeyUp   73  False   False   False  Oct Sun 30:18:36:08.691933
# 40678  KeyDown   85  False   False   False  Oct Sun 30:18:36:08.779938
# 40679    KeyUp   33  False   False   False  Oct Sun 30:18:36:08.891944
# 40680    KeyUp   69  False   False   False  Oct Sun 30:18:36:08.971949
# 40681  KeyDown   89  False   False   False  Oct Sun 30:18:36:08.985949
# 40682  KeyDown   68  False   False   False  Oct Sun 30:18:36:09.001950
# 40683    KeyUp   85  False   False   False  Oct Sun 30:18:36:09.091956
# 40684    KeyUp   89  False   False   False  Oct Sun 30:18:36:09.105956
# 40685    KeyUp   68  False   False   False  Oct Sun 30:18:36:09.118957
# 40686  KeyDown   69  False   False   False  Oct Sun 30:18:36:09.131958
# 40687    KeyUp   69  False   False   False  Oct Sun 30:18:36:09.145959
# 40688  KeyDown   33  False   False   False  Oct Sun 30:18:36:09.147959
# 40689  KeyDown   89  False   False   False  Oct Sun 30:18:36:09.203962
# 40690  KeyDown   69  False   False   False  Oct Sun 30:18:36:09.209962
# 40691  KeyDown   73  False   False   False  Oct Sun 30:18:36:09.219963
# 40692    KeyUp   73  False   False   False  Oct Sun 30:18:36:09.243964
# 40693    KeyUp   33  False   False   False  Oct Sun 30:18:36:09.307968
# 40694    KeyUp   89  False   False   False  Oct Sun 30:18:36:09.355971
# 40695    KeyUp   69  False   False   False  Oct Sun 30:18:36:09.368971
# 40696  KeyDown   73  False   False   False  Oct Sun 30:18:36:09.378972
# 40697  KeyDown   33  False   False   False  Oct Sun 30:18:36:09.396973
# 40698  KeyDown   71  False   False   False  Oct Sun 30:18:36:09.491978
# 40699    KeyUp   73  False   False   False  Oct Sun 30:18:36:09.515980
# 40700  KeyDown   69  False   False   False  Oct Sun 30:18:36:09.520980
# 40701    KeyUp   71  False   False   False  Oct Sun 30:18:36:09.651988
# 40702    KeyUp   69  False   False   False  Oct Sun 30:18:36:09.699990
# 40703    KeyUp   33  False   False   False  Oct Sun 30:18:36:09.763994
#
#        Unnamed: 6
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# ...           ...
# 40674         NaN
# 40675         NaN
# 40676         NaN
# 40677         NaN
# 40678         NaN
# 40679         NaN
# 40680         NaN
# 40681         NaN
# 40682         NaN
# 40683         NaN
# 40684         NaN
# 40685         NaN
# 40686         NaN
# 40687         NaN
# 40688         NaN
# 40689         NaN
# 40690         NaN
# 40691         NaN
# 40692         NaN
# 40693         NaN
# 40694         NaN
# 40695         NaN
# 40696         NaN
# 40697         NaN
# 40698         NaN
# 40699         NaN
# 40700         NaN
# 40701         NaN
# 40702         NaN
# 40703         NaN
#
# [40704 rows x 7 columns]

# %%
if len(df.columns)>6:
    for i in range(len(df.columns)-1,5,-1):
        df=df.drop(df.columns[[i]],axis=1)
df.columns=columns;

# %%
dates=df.Time.tolist()

# %%
dates=pd.Series(timevalue(dates))

# %%
df=df.reset_index()
df.Time=dates
df=df.drop('index',axis=1)

# %%
final_features=pd.DataFrame(columns=('lr','rl','lR','Lr','rL','Rl','lL','rR','ll','rr','l','r','L','R','Space','Enter',
                                     'Backspace','cpm'))

label=4  #Change for different users

#initial value
index=-1
count=0

# %%
df
# Out:
#       Event_Type  Key_Code  Shift    Alt Control          Time
# 0        KeyDown        68  False  False    True  2.593469e+06
# 1          KeyUp        68  False  False    True  2.593469e+06
# 2          KeyUp       163  False  False    True  2.593469e+06
# 3        KeyDown       163  False  False   False  2.593472e+06
# 4        KeyDown        87  False  False    True  2.593473e+06
# 5          KeyUp        87  False  False    True  2.593473e+06
# 6          KeyUp       163  False  False    True  2.593473e+06
# 7        KeyDown       163  False  False   False  2.593482e+06
# 8        KeyDown        68  False  False    True  2.593482e+06
# 9          KeyUp        68  False  False    True  2.593482e+06
# 10         KeyUp       163  False  False    True  2.593482e+06
# 11       KeyDown       163  False  False   False  2.593486e+06
# 12       KeyDown        87  False  False    True  2.593486e+06
# 13         KeyUp        87  False  False    True  2.593486e+06
# 14         KeyUp       163  False  False    True  2.593487e+06
# 15       KeyDown        78  False  False   False  2.593516e+06
# 16         KeyUp        78  False  False   False  2.593516e+06
# 17       KeyDown         9  False  False   False  2.593516e+06
# 18         KeyUp         9  False  False   False  2.593516e+06
# 19       KeyDown        81  False  False   False  2.593517e+06
# 20         KeyUp        81  False  False   False  2.593517e+06
# 21       KeyDown        83  False  False   False  2.593517e+06
# 22         KeyUp        83  False  False   False  2.593517e+06
# 23       KeyDown        70  False  False   False  2.593517e+06
# 24         KeyUp        70  False  False   False  2.593517e+06
# 25       KeyDown        78  False  False   False  2.593517e+06
# 26         KeyUp        78  False  False   False  2.593517e+06
# 27       KeyDown        74  False  False   False  2.593517e+06
# 28         KeyUp        74  False  False   False  2.593517e+06
# 29       KeyDown        69  False  False   False  2.593517e+06
# ...          ...       ...    ...    ...     ...           ...
# 40674      KeyUp        33  False  False   False  5.164569e+06
# 40675    KeyDown        69  False  False   False  5.164569e+06
# 40676    KeyDown        33  False  False   False  5.164569e+06
# 40677      KeyUp        73  False  False   False  5.164569e+06
# 40678    KeyDown        85  False  False   False  5.164569e+06
# 40679      KeyUp        33  False  False   False  5.164569e+06
# 40680      KeyUp        69  False  False   False  5.164569e+06
# 40681    KeyDown        89  False  False   False  5.164569e+06
# 40682    KeyDown        68  False  False   False  5.164569e+06
# 40683      KeyUp        85  False  False   False  5.164569e+06
# 40684      KeyUp        89  False  False   False  5.164569e+06
# 40685      KeyUp        68  False  False   False  5.164569e+06
# 40686    KeyDown        69  False  False   False  5.164569e+06
# 40687      KeyUp        69  False  False   False  5.164569e+06
# 40688    KeyDown        33  False  False   False  5.164569e+06
# 40689    KeyDown        89  False  False   False  5.164569e+06
# 40690    KeyDown        69  False  False   False  5.164569e+06
# 40691    KeyDown        73  False  False   False  5.164569e+06
# 40692      KeyUp        73  False  False   False  5.164569e+06
# 40693      KeyUp        33  False  False   False  5.164569e+06
# 40694      KeyUp        89  False  False   False  5.164569e+06
# 40695      KeyUp        69  False  False   False  5.164569e+06
# 40696    KeyDown        73  False  False   False  5.164569e+06
# 40697    KeyDown        33  False  False   False  5.164569e+06
# 40698    KeyDown        71  False  False   False  5.164569e+06
# 40699      KeyUp        73  False  False   False  5.164570e+06
# 40700    KeyDown        69  False  False   False  5.164570e+06
# 40701      KeyUp        71  False  False   False  5.164570e+06
# 40702      KeyUp        69  False  False   False  5.164570e+06
# 40703      KeyUp        33  False  False   False  5.164570e+06
#
# [40704 rows x 6 columns]

# %%
while index<len(df)-1:
    
    tmp_df=pd.DataFrame(columns=('Evenot_Type','Key_Code','Shift','Time'))
    feature_list=np.zeros((2,11))
    mean_latencies=np.zeros(11)
    i=0    
    index=index+1
    
    tmp=[df.Event_Type[index],df.Key_Code[index],df.Shift[index],df.Time[index]]
    tmp_df.loc[i]=tmp

    i=i+1

    while 1:
        
        if index>len(df)-1:
            break
        
        tmp=[df.Event_Type[index],df.Key_Code[index],df.Shift[index],df.Time[index]]
        if tmp[3]-tmp_df.Time[i-1]>10:
            break
        
        if tmp[3]-tmp_df.Time[0]>60:
            break
        
        tmp_df.loc[i]=tmp
        i=i+1
        index=index+1
            
    
    
    if len(tmp_df.Time)<50:
        continue
    
   ############################################################################
    #Calculating latencies of the different features

    #ipdb.set_trace()
    
    for j in range(0,len(tmp_df.Time)-1):
        
        flag=0
        
        if tmp_df.Event_Type[j]=='KeyDown':
            for k in range(j+1,len(tmp_df.Time)):
                if tmp_df.Event_Type[k]=='KeyDown':
                    flag=1
                    cha rs=[tmp_df.Key_Code[j],tmp_df.Shift[j],tmp_df.Key_Code[k],tmp_df.Shift[k]]
                    latency=tmp_df.Time[k]-tmp_df.Time[j]
                    break
                
        if flag==1 and latency<1.5:
            #print chars
            feature=categorize(chars)
            #print feature
            #print latency
            #print feature
            feature_list[0][feature]=feature_list[0][feature]+latency
            feature_list[1][feature]=feature_list[1][feature]+1
            #print feature_list
    mean_latencies=feature_list[0]/feature_list[1]
   ############################################################################            
    
    #Calculating hold times and number of backspaces and cpm
    feature_list_holdtime=np.zeros((2,7))
    backspaces=0
    characters=0
    cpm=float('NaN')
    backspace_per_character=float('NaN')
    
    for j in range(0,len(tmp_df.Time)-1):
        
        flag=0
        
        if tmp_df.Event_Type[j]=='KeyDown':
            key=tmp_df.Key_Code[j]    
            for k in range(j+1,len(tmp_df.Time)):
                if tmp_df.Key_Code[k]==key:
                    flag=1
                    chars=[key,tmp_df.Shift[j]]
                    holdtime=tmp_df.Time[k]-tmp_df.Time[j]
                    break
        
            characters=characters+1
            
            if key==9:
                backspaces=backspaces+1
                
        if flag==1 and holdtime<1.5:
            feature=lr_holdtime(chars)
            feature_list_holdtime[0][feature]=feature_list_holdtime[0][feature]+holdtime
            feature_list_holdtime[1][feature]=feature_list_holdtime[1][feature]+1
        
    mean_holdtime=feature_list_holdtime[0]/feature_list_holdtime[1]
        
    if characters>100:
        cpm=characters/(tmp_df.Time[len(tmp_df.Time)-1]-tmp_df.Time[0])*60
        backspace_per_character=float(backspaces)/characters
    
   ############################################################################
    
    mean_latencies=np.delete(mean_latencies,0,0)
    mean_holdtime=np.delete(mean_holdtime,0,0)    
    total_features=np.append(mean_latencies,mean_holdtime)
    total_features=np.append(total_features,backspace_per_character)
    total_features=np.append(total_features,cpm)
    
        
    
    final_features.loc[count]=total_features
    count=count+1    
    
    print count,'-',index, '-',len(tmp_df.Time)
    

           
#final_features.to_csv('tmp_final.csv')
new_final_features=final_features.dropna(how='all')
new_final_features=new_final_features.reset_index()
tmp=np.empty(len(new_final_features))
tmp.fill(label)

new_final_features['y'] = pd.Series(tmp)
new_final_features_median=new_final_features.fillna(final_features.median())
new_final_features_median.to_csv('final_median_4.csv',index=False)
new_final_features_mean=new_final_features.fillna(final_features.mean())
new_final_features_mean.to_csv('final_mean_4.csv',index=False)

print 'done'
# Out:
# 1 - 66 - 51
# 2 - 368 - 262
# 3 - 765 - 397
# 4 - 1036 - 271
# 5 - 1308 - 272
# 6 - 1428 - 120
# 7 - 1564 - 136
# 8 - 1958 - 394
# 9 - 2284 - 326
# 10 - 2472 - 188
# 11 - 2868 - 396
# 12 - 3338 - 422
# 13 - 3651 - 313
# 14 - 3974 - 323
# 15 - 4396 - 422
# 16 - 4776 - 380
# 17 - 5188 - 412
# 18 - 5314 - 126
# 19 - 5940 - 626
# 20 - 7104 - 1164
# 21 - 8242 - 1138
# 22 - 9341 - 1099
# 23 - 10317 - 976
# 24 - 11576 - 1259
# 25 - 12711 - 1135
# 26 - 12887 - 176
# 27 - 13929 - 1042
# 28 - 15507 - 1572
# 29 - 16801 - 1294
# 30 - 18107 - 1306
# 31 - 18511 - 404
# 32 - 19326 - 784
# 33 - 19827 - 501
# 34 - 20378 - 551
# 35 - 20829 - 451
# 36 - 21556 - 727
# 37 - 22353 - 797
# 38 - 23269 - 916
# 39 - 23981 - 712
# 40 - 24584 - 603
# 41 - 25262 - 678
# 42 - 26183 - 921
# 43 - 27006 - 823
# 44 - 28179 - 1173
# 45 - 28975 - 796
# 46 - 29535 - 560
# 47 - 29701 - 166
# 48 - 30639 - 938
# 49 - 30703 - 64
# 50 - 31393 - 690
# 51 - 32165 - 772
# 52 - 32311 - 146
# 53 - 33291 - 980
# 54 - 34057 - 766
# 55 - 34927 - 870
# 56 - 35987 - 1060
# 57 - 36961 - 974
# 58 - 37970 - 1009
# 59 - 38899 - 929
# 60 - 40041 - 1142
# 61 - 40704 - 663
# done
